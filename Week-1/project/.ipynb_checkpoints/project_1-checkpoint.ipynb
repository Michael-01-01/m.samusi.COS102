# %%
p = float(input("Input principal"))
r = float(input("Input rate"))
t =float(input("Input time"))

a = p*(1 + (r/100)*t )
si = a - p
print("The simple interest is ",si)
# Out:
# Input principal 2
# Input rate 3
# Input time 4
# The simple interest is  0.2400000000000002
