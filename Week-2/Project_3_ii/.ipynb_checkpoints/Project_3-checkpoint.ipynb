# %%
import pandas as pd


def main():

    data = {
        'Girls Name': ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Wuraola", "Alice", "Akua", "Grace"],
        'Girls Age': [17, 25, 18, 20, 21, 18, 19, 17, 18, 19],
        'Boys Name': ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kalu", "Efe", "Ahmed", "Chidi", "Tobi"],
        'Boys Age': [19, 18, 20, 22, 21, 18, 19, 17, 18, 19]
    }

   
    df = pd.DataFrame(data)

    print("\n--- YUMMY TREATS STUDENT DATA ---")
    print(df.to_string(index=False))

   

if __name__ == "__main__":
    main()
# Out:
# --- YUMMY TREATS STUDENT DATA ---
# Girls Name  Girls Age Boys Name  Boys Age
#     Evelyn         17   Chinedu        19
#    Jessica         25      Liam        18
#      Somto         18      Wale        20
#      Edith         20    Gbenga        22
#       Liza         21    Abiola        21
#    Madonna         18      Kalu        18
#    Wuraola         19       Efe        19
#      Alice         17     Ahmed        17
#       Akua         18     Chidi        18
#      Grace         19      Tobi        19

# %% [markdown]
# BEGIN
#     // Step 1: Import the Pandas library
#     IMPORT pandas AS pd
#
#     // Step 2: Define the data in a Dictionary format
#     // Key = Column Name, Value = List of data
#     SET student_data = {
#         "Girls Name": [Evelyn, Jessica, Somto, Edith, Liza, Madonna, Wuraola, Alice, Akua, Grace],
#         "Girls Age": [17, 25, 18, 20, 21, 18, 19, 17, 18, 19],
#         "Boys Name": [Chinedu, Liam, Wale, Gbenga, Abiola, Kalu, Efe, Ahmed, Chidi, Tobi],
#         "Boys Age": [19, 18, 20, 22, 21, 18, 19, 17, 18, 19]
#     }
#
#     // Step 3: Create a DataFrame object
#     SET df = CREATE_DATAFRAME(student_data)
#
#     // Step 4: Display the result
#     PRINT df
# END
