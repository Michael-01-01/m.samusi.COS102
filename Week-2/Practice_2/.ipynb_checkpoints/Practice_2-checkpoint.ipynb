# %%
city_1 = input("Enter name of city 1:")
city_2 = input("Enter name of city 2:")

temp = city_1
city_1 = city_2
city_2 = temp

print(f"The name of city 1 after swapping is: {city_1}")
print(f"The name of city 2 after swapping is: {city_2}")
# Out:
# Enter name of city 1: re
# Enter name of city 2: er
# The name of city 1 after swapping is: er
# The name of city 2 after swapping is: re

# %%
num = float(input("Enter a number: "))
if num > 0:
   print("Positive number")
elif num == 0:
   print("Zero")
else:
    print("Negative number")
# Out:
# Enter a number:  4
# Positive number

# %%
print("Welcome to the COUPE DE ESCRIVA 2023 FOOTBALL PICKS \n ")
captain = {'Madiba : ':'Chubby Obiaora-okafo','Blue Jays: ':'Christopher uweh',
           'Cirok:': 'Alexander','TSG Walkers :' : 'Ikechukwu'}

goalkeepers = {'Madiba : ':'Chubby Obiaora-okafo','Blue Jays: ':'Oladimeji Abaniwondea/Jeffrey Awagu',
           'Cirok:': 'Timileyi pearse/Izuako jeremy','TSG Walkers :' : 'Ayomide Ojituku'}

for pick in captain:
   print(pick,captain[pick])

print("\n")

for pick in goalkeepers:
   print(pick,goalkeepers[pick])
# Out:
# Welcome to the COUPE DE ESCRIVA 2023 FOOTBALL PICKS
#
# Madiba :  Chubby Obiaora-okafo
# Blue Jays:  Christopher uweh
# Cirok: Alexander
# TSG Walkers : Ikechukwu
#
#
# Madiba :  Chubby Obiaora-okafo
# Blue Jays:  Oladimeji Abaniwondea/Jeffrey Awagu
# Cirok: Timileyi pearse/Izuako jeremy
# TSG Walkers : Ayomide Ojituku
